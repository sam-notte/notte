# %%
import asyncio
from notte.env import NotteEnv
from examples.agent import SimpleNotteAgent
from examples.credentials import get_credentials

# For Jupyter notebooks, use await directly
username, password = get_credentials()

agent = SimpleNotteAgent(
    model="openai/gpt-4o-mini",
    max_steps=10,
    headless=False
)

# Run the agent directly with await
task = "Post 'Hello World' on Twitter"
result = await agent.run(
    task=task,
    url="https://twitter.com",
    credentials=username,
    password=password
)
print(result)
# Out:
# 2025-01-29 16:05:14.247 | INFO     | notte.browser.driver:__init__:43 - Using local browser pool. Consider using a shared pool for better resource management and performance by setting `browser_pool=BrowserPool(verbose=True)`
# 2025-01-29 16:05:14.251 | INFO     | examples.agent:run:158 - 🚀 starting agent with task: Post 'Hello World' on Twitter and url: https://twitter.com
# 2025-01-29 16:05:15.998 | DEBUG    | examples.agent:ask_notte:122 - Picking Notte endpoint: rules
# 2025-01-29 16:05:15.999 | DEBUG    | examples.agent:ask_notte:137 - Unknown provided endpoint: rules so we'll just recap the rules...
# 2025-01-29 16:05:15.999 | INFO     | examples.agent:run:181 - > step 0: looping in
# 2025-01-29 16:05:17.432 | INFO     | examples.agent:run:185 - 🤖 <url>https://twitter.com</url>
# 2025-01-29 16:05:17.433 | DEBUG    | examples.agent:ask_notte:122 - Picking Notte endpoint: observe
# 2025-01-29 16:05:26.006 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `progressbar`, name `Loading` and empty children.
# 2025-01-29 16:05:26.023 | ERROR    | notte.browser.node_type:from_a11y_node:545 - Pre-Attribute 'valuetext' should be added to the node attributes. Fix this ASAP.
# 2025-01-29 16:05:26.024 | INFO     | notte.common.logging:wrapper:16 - function goto took 8.5907 seconds
# 2025-01-29 16:05:26.024 | DEBUG    | notte.env:observe:142 - ℹ️ previous actions IDs: []
# 2025-01-29 16:05:26.024 | DEBUG    | notte.env:observe:143 - ℹ️ context inodes IDs: []
# 2025-01-29 16:05:26.025 | ERROR    | notte.pipe.listing:forward:111 - No interaction nodes found in context. Returning empty action list.
# 2025-01-29 16:05:26.026 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 0 >= 0. Stop action listing prematurely.
# 2025-01-29 16:05:26.030 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 534 tokens
# 2025-01-29 16:05:32.831 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 6.81 seconds)
# 2025-01-29 16:05:33.004 | WARNING  | notte.browser.snapshot:compare_with:35 - Interactive nodes changed: {('', 'button', 'Forgot password?'), ('', 'button', 'Close'), ('', 'button', 'Sign up'), ('', 'button', 'Sign in with Apple'), ('', 'button', 'Next'), ('', 'textbox', 'Phone, email, or username')}
# 2025-01-29 16:05:33.004 | WARNING  | notte.env:_obslisting:121 - Snapshot changed since the beginning of the action listing, retrying to observe again
# 2025-01-29 16:05:33.012 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Phone, email, or username', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Phone, email, or username', 'children': [], 'id': 'I1'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:05:33.094 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1516 tokens
# 2025-01-29 16:05:48.604 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 6 >= 5. Stop action listing prematurely.
# 2025-01-29 16:05:48.607 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 592 tokens
# 2025-01-29 16:05:54.037 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 5.43 seconds)
# 2025-01-29 16:05:54.192 | INFO     | notte.common.logging:wrapper:16 - function observe took 36.7590 seconds
# 2025-01-29 16:05:54.193 | INFO     | examples.agent:run:199 - 🌌
# Webpage information:
# - URL: https://x.com/i/flow/login
# - Title: Log in to X / X
# - Description: This document represents a login interface for a web application titled "Sign in to X." Users are expected to enter their credentials—such as a phone number, email, or username—and can choose to sign in with Apple or navigate to create a new account if they don't have one. The interface also offers a password recovery option.
# - Timestamp: 2025-01-29 16:05:33
# - Page category: auth
#
# Here are the available actions you can take on this paqe:
#
# <actions>
# # User Account
# * B1: Close the sign-in dialog
# * B2: Sign in using Apple account
# * B3: Continue to the next step after entering credentials
# * B5: Redirect to sign-up page for new users
# * I1: Enter phone, email, or username for sign-in ([ActionParameter(name='credentials', type='str', default=None, values=[])])
#
# # Help &amp; Support
# * B4: Initiate password recovery process
#
# # Special Browser Actions
# * S1: Go to a specific URL ([ActionParameter(name='url', type='string', default=None, values=[])])
# * S2: Scrape data from the current page
# * S3: Take a screenshot of the current page
# * S4: Go to the previous page
# * S5: Go to the next page
# * S6: Refresh the current page
# * S7: Wait for a specific amount of time (in seconds) ([ActionParameter(name='wait_time_seconds', type='int', default=None, values=[])])
# * S8: Terminate the current session
# </actions>
#
# Now think about your current trajectory, and decide what action to take next.
# You might need to perform some intermediate actions so be very careful, dont jump to conclusions too quickly.
#
# Provide me with the ID of the action you want to take next.
# You are allowed to take only exactly ONE action from this list (not previous lists)!
# If the action is parameterized, provide the value for each parameter.
# Use the exact following format:
#
# <execute-action>
# {
# "action_id": "<YOUR_ACTION_ID>",
# "params": { "<YOUR_PARAM_NAME>": "<YOUR_PARAM_VALUE>" }
# }
# </execute-action>
#
# Important rules:
# * If you're done, include you final answer in <done> tags.
# Don't forget to justify why your answer is correct and solves the task.
# Don't assume anything, just provide factual information backup by the page you're on.
# * If you are not done, provide the action you want to take next in <execute-action> tags.
# * If you want to stop or you're unable to pursue your goal, just explain your problem
# inside <done>Error: ... </done> tags.
# * You are allowed to take only exactly ONE action from the list.
# * You are ONLY allowed to pick actions from the latest list of actions!
# * You are NOT allowed to pick actions from list of actions in previous messages!
# * If you feel stuck, remember that you are allowed to use `Special Browser Actions` at any time to:
#     * Go to a different url
#     * Go back to the previous page
#     * Refresh the current page
#     * Scrape data from the page
#     * Etc
#
#
# 2025-01-29 16:05:54.193 | INFO     | examples.agent:run:181 - > step 1: looping in
# 2025-01-29 16:05:55.164 | INFO     | examples.agent:run:185 - 🤖 <execute-action>
# {
# "action_id": "I1",
# "params": { "credentials": "ella_mulle30411" }
# }
# </execute-action>
# 2025-01-29 16:05:55.164 | DEBUG    | examples.agent:ask_notte:122 - Picking Notte endpoint: step
# 2025-01-29 16:05:57.505 | INFO     | notte.env:execute:160 - 🌌 action I1 executed in browser
# 2025-01-29 16:05:57.514 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Username', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Username', 'disabled': True, 'children': [], 'value': 'ella_mulle30411', 'id': 'I1'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:05:57.515 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Password', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Password Reveal password', 'focused': True, 'children': [], 'id': 'I2'}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'button', 'name': 'Reveal password', 'children': [], 'id': 'B2'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:05:57.626 | INFO     | notte.common.logging:wrapper:16 - function execute took 2.4609 seconds
# 2025-01-29 16:05:57.627 | DEBUG    | notte.env:step:231 - ℹ️ previous actions IDs: ['B1', 'B2', 'B3', 'B4', 'B5', 'I1']
# 2025-01-29 16:05:57.627 | DEBUG    | notte.env:step:232 - ℹ️ context inodes IDs: ['B1', 'I1', 'I2', 'B2', 'B3', 'B4', 'B5']
# 2025-01-29 16:05:57.637 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 63.42%
# 2025-01-29 16:05:57.646 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1607 tokens
# 2025-01-29 16:06:02.414 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 7 >= 6. Stop action listing prematurely.
# 2025-01-29 16:06:02.417 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 565 tokens
# 2025-01-29 16:06:11.551 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 9.14 seconds)
# 2025-01-29 16:06:11.803 | INFO     | notte.common.logging:wrapper:16 - function step took 16.6377 seconds
# 2025-01-29 16:06:11.804 | INFO     | examples.agent:run:199 - 🌌
# Webpage information:
# - URL: https://x.com/i/flow/login
# - Title: Log in to X / X
# - Description: This document presents a modal dialog requiring users to enter their password for logging into the "X" system. Users are expected to input their password into the designated textbox and can reveal the password if needed.
# - Timestamp: 2025-01-29 16:05:57
# - Page category: auth
#
# Here are the available actions you can take on this paqe:
#
# <actions>
# # User Account
# * B1: Close the sign-in dialog
# * B2: Sign in using Apple account
# * B3: Continue to the next step after entering credentials
# * B5: Redirect to sign-up page for new users
# * I1: Enter phone, email, or username for sign-in ([ActionParameter(name='credentials', type='str', default=None, values=[])])
# * I2: Enter password to log in ([ActionParameter(name='password', type='str', default=None, values=[])])
#
# # Help &amp; Support
# * B4: Initiate password recovery process
#
# # Special Browser Actions
# * S1: Go to a specific URL ([ActionParameter(name='url', type='string', default=None, values=[])])
# * S2: Scrape data from the current page
# * S3: Take a screenshot of the current page
# * S4: Go to the previous page
# * S5: Go to the next page
# * S6: Refresh the current page
# * S7: Wait for a specific amount of time (in seconds) ([ActionParameter(name='wait_time_seconds', type='int', default=None, values=[])])
# * S8: Terminate the current session
# </actions>
#
# Now think about your current trajectory, and decide what action to take next.
# You might need to perform some intermediate actions so be very careful, dont jump to conclusions too quickly.
#
# Provide me with the ID of the action you want to take next.
# You are allowed to take only exactly ONE action from this list (not previous lists)!
# If the action is parameterized, provide the value for each parameter.
# Use the exact following format:
#
# <execute-action>
# {
# "action_id": "<YOUR_ACTION_ID>",
# "params": { "<YOUR_PARAM_NAME>": "<YOUR_PARAM_VALUE>" }
# }
# </execute-action>
#
# Important rules:
# * If you're done, include you final answer in <done> tags.
# Don't forget to justify why your answer is correct and solves the task.
# Don't assume anything, just provide factual information backup by the page you're on.
# * If you are not done, provide the action you want to take next in <execute-action> tags.
# * If you want to stop or you're unable to pursue your goal, just explain your problem
# inside <done>Error: ... </done> tags.
# * You are allowed to take only exactly ONE action from the list.
# * You are ONLY allowed to pick actions from the latest list of actions!
# * You are NOT allowed to pick actions from list of actions in previous messages!
# * If you feel stuck, remember that you are allowed to use `Special Browser Actions` at any time to:
#     * Go to a different url
#     * Go back to the previous page
#     * Refresh the current page
#     * Scrape data from the page
#     * Etc
#
#
# 2025-01-29 16:06:11.804 | INFO     | examples.agent:run:181 - > step 2: looping in
# 2025-01-29 16:06:13.209 | INFO     | examples.agent:run:185 - 🤖 <execute-action>
# {
# "action_id": "I2",
# "params": { "password": "EPFLtonio2001" }
# }
# </execute-action>
# 2025-01-29 16:06:13.211 | DEBUG    | examples.agent:ask_notte:122 - Picking Notte endpoint: step
# 2025-01-29 16:06:15.521 | INFO     | notte.env:execute:160 - 🌌 action I2 executed in browser
# 2025-01-29 16:06:15.531 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Username', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Username', 'disabled': True, 'children': [], 'value': 'ella_mulle30411', 'id': 'I1'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:06:15.531 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Password', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Password Reveal password', 'focused': True, 'children': [], 'id': 'I2'}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'button', 'name': 'Reveal password', 'children': [], 'id': 'B2'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:06:15.615 | INFO     | notte.common.logging:wrapper:16 - function execute took 2.4038 seconds
# 2025-01-29 16:06:15.616 | DEBUG    | notte.env:step:231 - ℹ️ previous actions IDs: ['I2', 'B1', 'B2', 'B3', 'B4', 'B5', 'I1']
# 2025-01-29 16:06:15.616 | DEBUG    | notte.env:step:232 - ℹ️ context inodes IDs: ['B1', 'I1', 'I2', 'B2', 'B3', 'B4', 'B5']
# 2025-01-29 16:06:15.616 | ERROR    | notte.browser.context:subgraph_without:72 - No nodes left in context after filtering of exesting actions for url https://x.com/i/flow/login
# 2025-01-29 16:06:15.617 | ERROR    | notte.pipe.listing:forward_incremental:131 - No nodes left in context after filtering of exesting actions for url https://x.com/i/flow/login. Returning previous action list...
# 2025-01-29 16:06:15.618 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 7 >= 6. Stop action listing prematurely.
# 2025-01-29 16:06:15.620 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 526 tokens
# 2025-01-29 16:06:19.369 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 3.75 seconds)
# 2025-01-29 16:06:19.522 | WARNING  | notte.browser.snapshot:compare_with:35 - Interactive nodes changed: {('', 'button', 'Hide password'), ('', 'textbox', 'Password Hide password')}
# 2025-01-29 16:06:19.522 | WARNING  | notte.env:_obslisting:121 - Snapshot changed since the beginning of the action listing, retrying to observe again
# 2025-01-29 16:06:19.532 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Username', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Username', 'disabled': True, 'children': [], 'value': 'ella_mulle30411', 'id': 'I1'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:06:19.532 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Password', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Password Hide password', 'focused': True, 'children': [], 'id': 'I2'}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'button', 'name': 'Hide password', 'children': [], 'id': 'B2'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:06:19.633 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `tooltip`, name `Hide password` and empty children.
# 2025-01-29 16:06:19.633 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `tooltip`, name `Hide password` and empty children.
# 2025-01-29 16:06:19.633 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `tooltip`, name `Hide password` and empty children.
# 2025-01-29 16:06:19.633 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `tooltip`, name `Hide password` and empty children.
# 2025-01-29 16:06:19.635 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `tooltip`, name `Hide password` and empty children.
# 2025-01-29 16:06:19.637 | ERROR    | notte.browser.context:subgraph_without:72 - No nodes left in context after filtering of exesting actions for url https://x.com/i/flow/login
# 2025-01-29 16:06:19.637 | ERROR    | notte.pipe.listing:forward_incremental:131 - No nodes left in context after filtering of exesting actions for url https://x.com/i/flow/login. Returning previous action list...
# 2025-01-29 16:06:19.638 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 7 >= 6. Stop action listing prematurely.
# 2025-01-29 16:06:19.640 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 526 tokens
# 2025-01-29 16:06:43.928 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 24.29 seconds)
# 2025-01-29 16:06:44.119 | INFO     | notte.common.logging:wrapper:16 - function step took 30.9078 seconds
# 2025-01-29 16:06:44.120 | INFO     | examples.agent:run:199 - 🌌
# Webpage information:
# - URL: https://x.com/i/flow/login
# - Title: Log in to X / X
# - Description: No description available
# - Timestamp: 2025-01-29 16:06:19
# - Page category: auth
#
# Here are the available actions you can take on this paqe:
#
# <actions>
# # User Account
# * B1: Close the sign-in dialog
# * B2: Sign in using Apple account
# * B3: Continue to the next step after entering credentials
# * B5: Redirect to sign-up page for new users
# * I1: Enter phone, email, or username for sign-in ([ActionParameter(name='credentials', type='str', default=None, values=[])])
# * I2: Enter password to log in ([ActionParameter(name='password', type='str', default=None, values=[])])
#
# # Help &amp; Support
# * B4: Initiate password recovery process
#
# # Special Browser Actions
# * S1: Go to a specific URL ([ActionParameter(name='url', type='string', default=None, values=[])])
# * S2: Scrape data from the current page
# * S3: Take a screenshot of the current page
# * S4: Go to the previous page
# * S5: Go to the next page
# * S6: Refresh the current page
# * S7: Wait for a specific amount of time (in seconds) ([ActionParameter(name='wait_time_seconds', type='int', default=None, values=[])])
# * S8: Terminate the current session
# </actions>
#
# Now think about your current trajectory, and decide what action to take next.
# You might need to perform some intermediate actions so be very careful, dont jump to conclusions too quickly.
#
# Provide me with the ID of the action you want to take next.
# You are allowed to take only exactly ONE action from this list (not previous lists)!
# If the action is parameterized, provide the value for each parameter.
# Use the exact following format:
#
# <execute-action>
# {
# "action_id": "<YOUR_ACTION_ID>",
# "params": { "<YOUR_PARAM_NAME>": "<YOUR_PARAM_VALUE>" }
# }
# </execute-action>
#
# Important rules:
# * If you're done, include you final answer in <done> tags.
# Don't forget to justify why your answer is correct and solves the task.
# Don't assume anything, just provide factual information backup by the page you're on.
# * If you are not done, provide the action you want to take next in <execute-action> tags.
# * If you want to stop or you're unable to pursue your goal, just explain your problem
# inside <done>Error: ... </done> tags.
# * You are allowed to take only exactly ONE action from the list.
# * You are ONLY allowed to pick actions from the latest list of actions!
# * You are NOT allowed to pick actions from list of actions in previous messages!
# * If you feel stuck, remember that you are allowed to use `Special Browser Actions` at any time to:
#     * Go to a different url
#     * Go back to the previous page
#     * Refresh the current page
#     * Scrape data from the page
#     * Etc
#
#
# 2025-01-29 16:06:44.120 | INFO     | examples.agent:run:181 - > step 3: looping in
# 2025-01-29 16:06:45.030 | INFO     | examples.agent:run:185 - 🤖 <execute-action>
# {
# "action_id": "B3",
# "params": {}
# }
# </execute-action>
# 2025-01-29 16:06:45.031 | DEBUG    | examples.agent:ask_notte:122 - Picking Notte endpoint: step
# 2025-01-29 16:06:46.532 | INFO     | notte.env:execute:160 - 🌌 action B3 executed in browser
# 2025-01-29 16:06:46.538 | INFO     | notte.common.logging:wrapper:16 - function execute took 1.5067 seconds
# 2025-01-29 16:06:46.538 | DEBUG    | notte.env:step:231 - ℹ️ previous actions IDs: []
# 2025-01-29 16:06:46.539 | DEBUG    | notte.env:step:232 - ℹ️ context inodes IDs: []
# 2025-01-29 16:06:46.539 | ERROR    | notte.pipe.listing:forward:111 - No interaction nodes found in context. Returning empty action list.
# 2025-01-29 16:06:46.540 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 0 >= 0. Stop action listing prematurely.
# 2025-01-29 16:06:46.543 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 609 tokens
# 2025-01-29 16:06:50.958 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 4.42 seconds)
# 2025-01-29 16:06:51.156 | WARNING  | notte.browser.snapshot:compare_with:35 - Interactive nodes changed: {('', 'radio', 'Send an email to el**********@p*****.**'), ('', 'button', 'Cancel'), ('', 'button', 'Close'), ('', 'link', 'X Support'), ('', 'button', 'Next')}
# 2025-01-29 16:06:51.157 | WARNING  | notte.env:_obslisting:121 - Snapshot changed since the beginning of the action listing, retrying to observe again
# 2025-01-29 16:06:51.164 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Send an email to el**********@p*****.**', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': []}]}, {'role': 'radio', 'name': 'Send an email to el**********@p*****.**', 'checked': True, 'children': [], 'id': 'B2'}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 16:06:51.237 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1563 tokens
# 2025-01-29 16:06:57.027 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1 | Close the confirmation code dialog | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:06:57.029 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2 | Select to send the confirmation code via email | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:06:57.030 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B3 | Navigate to the next step in the confirmation process | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:06:57.030 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B4 | Cancel the confirmation process | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:06:57.030 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L1 | Contact X Support for assistance | None | Help & Support | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:06:57.034 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 5 : {'B2', 'B3', 'L1', 'B4', 'B1'}
# 2025-01-29 16:06:57.035 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 5 total, 4 required for completion but only 0 listed
# 2025-01-29 16:06:57.035 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 3 trials left.
# 2025-01-29 16:06:57.044 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1563 tokens
# 2025-01-29 16:07:03.466 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1 | Close the confirmation code dialog | None | Actions | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:07:03.468 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2 | Choose to receive a confirmation code via email | None | Actions | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:07:03.469 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B3 | Proceed to the next step in the password change process | None | Actions | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:07:03.469 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B4 | Cancel the dialog and exit the process | None | Actions | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:07:03.469 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L1 | Reach out to X Support for assistance | None | Help & Support | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 16:07:03.472 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 5 : {'B2', 'B3', 'L1', 'B4', 'B1'}
# 2025-01-29 16:07:03.473 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 5 total, 4 required for completion but only 0 listed
# 2025-01-29 16:07:03.473 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 2 trials left.
# 2025-01-29 16:07:03.494 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1563 tokens
# 2025-01-29 16:07:09.489 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 5 >= 4. Stop action listing prematurely.
# 2025-01-29 16:07:09.491 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 647 tokens
# 2025-01-29 16:07:22.475 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: overlay (took 12.98 seconds)
# 2025-01-29 16:07:22.605 | INFO     | notte.browser.pool:_close_browser:269 - Closing browser 6defaf11-64cf-49bd-af5b-030106481e11
# ---------------------------------------------------------------------------
# TargetClosedError                         Traceback (most recent call last)
# File ~/DEV/Notte/password_manager/notte/notte/browser/driver.py:131, in BrowserDriver.snapshot(self, screenshot, retries)
#     130 try:
# --> 131     html_content = await self.page.content()
#     132     a11y_simple: A11yNode | None = await self.page.accessibility.snapshot()  # type: ignore
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/playwright/async_api/_generated.py:8871, in Page.content(self)
#    8862 """Page.content
#    8863
#    8864 Gets the full HTML contents of the page, including the doctype.
#    (...)
#    8868 str
#    8869 """
# -> 8871 return mapping.from_maybe_impl(await self._impl_obj.content())
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/playwright/_impl/_page.py:534, in Page.content(self)
#     533 async def content(self) -> str:
# --> 534     return await self._main_frame.content()
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/playwright/_impl/_frame.py:416, in Frame.content(self)
#     415 async def content(self) -> str:
# --> 416     return await self._channel.send("content")
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/playwright/_impl/_connection.py:61, in Channel.send(self, method, params)
#      60 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 61     return await self._connection.wrap_api_call(
#      62         lambda: self._inner_send(method, params, False),
#      63         self._is_internal_type,
#      64     )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/playwright/_impl/_connection.py:528, in Connection.wrap_api_call(self, cb, is_internal)
#     527 except Exception as error:
# --> 528     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     529 finally:
#
# TargetClosedError: Page.content: Target page, context or browser has been closed
#
# The above exception was the direct cause of the following exception:
#
# BrowserExpiredError                       Traceback (most recent call last)
# Cell In[5], line 17
#      15 # Run the agent directly with await
#      16 task = "Post 'Hello World' on Twitter"
# ---> 17 result = await agent.run(
#      18     task=task,
#      19     url="https://twitter.com",
#      20     credentials=username,
#      21     password=password
#      22 )
#      23 print(result)
#
# File ~/DEV/Notte/password_manager/notte/examples/agent.py:197, in SimpleNotteAgent.run(self, task, url, credentials, password)
#     190     return AgentOutput(
#     191         answer=done_answer,
#     192         success=("Error: " not in done_answer),
#     193         snapshot=self.env.context.snapshot,
#     194         messages=messages,
#     195     )
#     196 # Ask Notte to perform the selected action
# --> 197 obs: str = await self.ask_notte(resp)
#     198 messages.append({"role": "user", "content": obs})
#     199 logger.info(f"🌌 {obs}")
#
# File ~/DEV/Notte/password_manager/notte/examples/agent.py:130, in SimpleNotteAgent.ask_notte(self, text)
#     128 case "step":
#     129     step_params = self.parser.step(text)
# --> 130     obs = await self.env.step(step_params.action_id, step_params.params)
#     131     return self.parser.textify(obs)
#     132 case "scrape":
#     133     # TODO: parse URL if needed
#
# File ~/DEV/Notte/password_manager/notte/notte/common/logging.py:14, in timeit.<locals>._timeit.<locals>.wrapper(*args, **kwargs)
#      12 async def wrapper(*args: Any, **kwargs: Any) -> Any:
#      13     start_time = time.time()
# ---> 14     result = await func(*args, **kwargs)
#      15     end_time = time.time()
#      16     logger.info(f"function {name} took {end_time - start_time:.4f} seconds")
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:233, in NotteEnv.step(self, action_id, params, enter, min_nb_actions, max_nb_actions)
#     231 logger.debug(f"ℹ️ previous actions IDs: {[a.id for a in self.previous_actions or []]}")
#     232 logger.debug(f"ℹ️ context inodes IDs: {[node.id for node in self.context.interaction_nodes()]}")
# --> 233 return await self._obslisting(min_nb_actions, max_nb_actions)
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:123, in NotteEnv._obslisting(self, min_nb_actions, max_nb_actions, retry)
#     121     logger.warning("Snapshot changed since the beginning of the action listing, retrying to observe again")
#     122     _ = self._preobserve(check_snapshot)
# --> 123     return await self._obslisting(retry=retry - 1, min_nb_actions=min_nb_actions, max_nb_actions=max_nb_actions)
#     125 if self.obs.space.category is not None and self.obs.space.category.is_data() and not self.obs.has_data():
#     126     self.obs.data = await self._data_scraping_pipe.forward(self.context, scrape_images=False)
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:119, in NotteEnv._obslisting(self, min_nb_actions, max_nb_actions, retry)
#     110 self.obs.space = self._context_to_action_space_pipe.forward(
#     111     self.context,
#     112     self.previous_actions,
#     113     min_nb_actions=min_nb_actions,
#     114     max_nb_actions=max_nb_actions,
#     115 )
#     116 # TODO: improve this
#     117 # Check if the snapshot has changed since the beginning of the trajectory
#     118 # if it has, it means that the page was not fully loaded and that we should restart the oblisting
# --> 119 check_snapshot = await self._browser.snapshot()
#     120 if not self.context.snapshot.compare_with(check_snapshot) and retry > 0:
#     121     logger.warning("Snapshot changed since the beginning of the action listing, retrying to observe again")
#
# File ~/DEV/Notte/password_manager/notte/notte/browser/driver.py:136, in BrowserDriver.snapshot(self, screenshot, retries)
#     134 except Exception as e:
#     135     if "has been closed" in str(e):
# --> 136         raise BrowserExpiredError() from e
#     137     raise UnexpectedBrowserError(url=self.page.url) from e
#     138 if a11y_simple is None or a11y_raw is None or len(a11y_simple.get("children", [])) == 0:
#
# BrowserExpiredError: Browser or context expired or closed. You should use `await browser.start()` to start a new session.
