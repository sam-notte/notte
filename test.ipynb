# %%
import asyncio
from notte.env import NotteEnv
from examples.agent import SimpleNotteAgent

# No need to explicitly get credentials anymore
agent = SimpleNotteAgent(
    model="openai/gpt-4o-mini",
    max_steps=10,
    headless=False
)

# Run the agent directly with await
task = "Post 'Hello World' on Twitter"
result = await agent.run(
    task=task,
    url="https://x.com"  # Credentials will be loaded automatically
)
print(result)
# Out:
# /Users/antoinemunier/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pydantic/_internal/_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'fields' has been removed
#   warnings.warn(message, UserWarning)
# 2025-01-29 17:05:03.601 | INFO     | notte.llms.service:<module>:19 - Using default LLAMUX config path: /Users/antoinemunier/DEV/Notte/password_manager/notte/notte/llms/config/endpoints.csv
# 2025-01-29 17:05:03.627 | INFO     | notte.browser.driver:__init__:43 - Using local browser pool. Consider using a shared pool for better resource management and performance by setting `browser_pool=BrowserPool(verbose=True)`
# 2025-01-29 17:05:03.628 | INFO     | examples.agent:run:162 - 🔑 Using credentials for https://x.com: ella_mulle30411 / EPFLtonio2001
# 2025-01-29 17:05:03.629 | INFO     | examples.agent:run:166 - 🚀 starting agent with task: Post 'Hello World' on Twitter and url: https://x.com
# 2025-01-29 17:05:04.828 | DEBUG    | examples.agent:ask_notte:124 - Picking Notte endpoint: rules
# 2025-01-29 17:05:04.830 | DEBUG    | examples.agent:ask_notte:139 - Unknown provided endpoint: rules so we'll just recap the rules...
# 2025-01-29 17:05:04.831 | INFO     | examples.agent:run:190 - > step 0: looping in
# 2025-01-29 17:05:13.517 | INFO     | examples.agent:run:194 - 🤖 <url>https://x.com</url>
# 2025-01-29 17:05:13.518 | DEBUG    | examples.agent:ask_notte:124 - Picking Notte endpoint: observe
# 2025-01-29 17:05:19.392 | ERROR    | notte.pipe.preprocessing.a11y.pruning:should_prune:63 - New pruning edge case for node, with role `progressbar`, name `Loading` and empty children.
# 2025-01-29 17:05:19.410 | ERROR    | notte.browser.node_type:from_a11y_node:545 - Pre-Attribute 'valuetext' should be added to the node attributes. Fix this ASAP.
# 2025-01-29 17:05:19.410 | INFO     | notte.common.logging:wrapper:16 - function goto took 5.8923 seconds
# 2025-01-29 17:05:19.411 | DEBUG    | notte.env:observe:142 - ℹ️ previous actions IDs: []
# 2025-01-29 17:05:19.411 | DEBUG    | notte.env:observe:143 - ℹ️ context inodes IDs: []
# 2025-01-29 17:05:19.411 | ERROR    | notte.pipe.listing:forward:111 - No interaction nodes found in context. Returning empty action list.
# 2025-01-29 17:05:19.412 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 0 >= 0. Stop action listing prematurely.
# 2025-01-29 17:05:19.417 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 534 tokens
# 2025-01-29 17:05:25.126 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 5.71 seconds)
# 2025-01-29 17:05:25.322 | WARNING  | notte.browser.snapshot:compare_with:35 - Interactive nodes changed: {('', 'textbox', 'Phone, email, or username'), ('', 'button', 'Close'), ('', 'button', 'Next'), ('', 'button', 'Sign up'), ('', 'button', 'Sign in with Apple'), ('', 'button', 'Forgot password?')}
# 2025-01-29 17:05:25.322 | WARNING  | notte.env:_obslisting:121 - Snapshot changed since the beginning of the action listing, retrying to observe again
# 2025-01-29 17:05:25.331 | ERROR    | notte.pipe.preprocessing.a11y.id_generation:generate_sequential_ids:66 - Unsupported role to convert to ID: {'role': 'LabelText', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'text', 'name': 'Phone, email, or username', 'children': []}]}]}, {'role': 'generic', 'name': '', 'children': [{'role': 'generic', 'name': '', 'children': [{'role': 'textbox', 'name': 'Phone, email, or username', 'children': [], 'id': 'I1'}]}]}]}]}. Please add this role to the ID generation logic ASAP.
# 2025-01-29 17:05:25.441 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1516 tokens
# 2025-01-29 17:05:34.162 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1  | Close the sign in dialog                           | None       | Help & Support     | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:34.171 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2  | Sign in to the application using Apple             | None       | User Account       | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:34.173 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B3  | Proceed to the next step in the sign-in process    | None       | User Account       | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:34.174 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B4  | Recover forgotten password                          | None       | Help & Support     | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:34.175 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B5  | Navigate to the sign-up page                       | None       | User Account       | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:34.177 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 5 : {'B3', 'B4', 'B2', 'B1', 'B5'}
# 2025-01-29 17:05:34.178 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 6 total, 5 required for completion but only 1 listed
# 2025-01-29 17:05:34.179 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 3 trials left.
# 2025-01-29 17:05:34.191 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 41.51%
# 2025-01-29 17:05:34.207 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1572 tokens
# 2025-01-29 17:05:43.086 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1 | Close the sign-in dialog | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:43.088 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2 | Sign in using Apple account | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:43.089 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B3 | Proceed to the next step of sign-in | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:43.089 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B4 | Recover forgotten password | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:43.089 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B5 | Sign up for a new account | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:43.091 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 5 : {'B3', 'B4', 'B2', 'B1', 'B5'}
# 2025-01-29 17:05:43.091 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 6 total, 5 required for completion but only 1 listed
# 2025-01-29 17:05:43.091 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 2 trials left.
# 2025-01-29 17:05:43.103 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 41.51%
# 2025-01-29 17:05:43.114 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1572 tokens
# 2025-01-29 17:05:50.287 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1 | Close the sign-in dialog | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:50.291 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2 | Sign in using Apple account | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:50.292 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B3 | Proceed to the next step in sign-in process | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:50.293 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B4 | Initiate password recovery process | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:50.293 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B5 | Access the sign-up page | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:05:50.295 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 5 : {'B3', 'B4', 'B2', 'B1', 'B5'}
# 2025-01-29 17:05:50.296 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 6 total, 5 required for completion but only 1 listed
# 2025-01-29 17:05:50.296 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 1 trials left.
# 2025-01-29 17:05:50.309 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 41.51%
# 2025-01-29 17:05:50.319 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1572 tokens
# 2025-01-29 17:05:58.608 | WARNING  | notte.pipe.listing:forward:206 - failed to parse action list but retrying. Start of error msg: Failed to parse LLM response. No content found within <document-summary> tags in the response: <characters-summary>
# The document provides a modal dialog for users to log in to the service X. It includ...
# 2025-01-29 17:05:58.624 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 41.51%
# 2025-01-29 17:05:58.634 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1572 tokens
# 2025-01-29 17:06:05.354 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 6 >= 5. Stop action listing prematurely.
# 2025-01-29 17:06:05.357 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 565 tokens
# 2025-01-29 17:06:11.897 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: auth (took 6.54 seconds)
# 2025-01-29 17:06:12.065 | INFO     | notte.common.logging:wrapper:16 - function observe took 58.5465 seconds
# 2025-01-29 17:06:12.065 | INFO     | examples.agent:run:208 - 🌌
# Webpage information:
# - URL: https://x.com/i/flow/login
# - Title: Log in to X / X
# - Description: This document represents the modal interface for logging into a service called "X". Users are expected to interact with different buttons for signing in, requesting help for forgotten passwords, and signing up for new accounts.
# - Timestamp: 2025-01-29 17:05:25
# - Page category: auth
#
# Here are the available actions you can take on this paqe:
#
# <actions>
# # User Account
# * B1: Close the sign-in modal
# * B2: Sign in using Apple credentials
# * B3: Proceed to the next step in the sign-in process
# * B4: Request help with forgotten password
# * B5: Navigate to the sign-up interface
# * I1: Enter phone, email, or username for sign in ([ActionParameter(name='userIdentifier', type='str', default=None, values=[])])
#
# # Special Browser Actions
# * S1: Go to a specific URL ([ActionParameter(name='url', type='string', default=None, values=[])])
# * S2: Scrape data from the current page
# * S3: Take a screenshot of the current page
# * S4: Go to the previous page
# * S5: Go to the next page
# * S6: Refresh the current page
# * S7: Wait for a specific amount of time (in seconds) ([ActionParameter(name='wait_time_seconds', type='int', default=None, values=[])])
# * S8: Terminate the current session
# </actions>
#
# Now think about your current trajectory, and decide what action to take next.
# You might need to perform some intermediate actions so be very careful, dont jump to conclusions too quickly.
#
# Provide me with the ID of the action you want to take next.
# You are allowed to take only exactly ONE action from this list (not previous lists)!
# If the action is parameterized, provide the value for each parameter.
# Use the exact following format:
#
# <execute-action>
# {
# "action_id": "<YOUR_ACTION_ID>",
# "params": { "<YOUR_PARAM_NAME>": "<YOUR_PARAM_VALUE>" }
# }
# </execute-action>
#
# Important rules:
# * If you're done, include you final answer in <done> tags.
# Don't forget to justify why your answer is correct and solves the task.
# Don't assume anything, just provide factual information backup by the page you're on.
# * If you are not done, provide the action you want to take next in <execute-action> tags.
# * If you want to stop or you're unable to pursue your goal, just explain your problem
# inside <done>Error: ... </done> tags.
# * You are allowed to take only exactly ONE action from the list.
# * You are ONLY allowed to pick actions from the latest list of actions!
# * You are NOT allowed to pick actions from list of actions in previous messages!
# * If you feel stuck, remember that you are allowed to use `Special Browser Actions` at any time to:
#     * Go to a different url
#     * Go back to the previous page
#     * Refresh the current page
#     * Scrape data from the page
#     * Etc
#
#
# 2025-01-29 17:06:12.065 | INFO     | examples.agent:run:190 - > step 1: looping in
# 2025-01-29 17:06:12.846 | INFO     | examples.agent:run:194 - 🤖 <execute-action>
# {
# "action_id": "B1",
# "params": {}
# }
# </execute-action>
# 2025-01-29 17:06:12.847 | DEBUG    | examples.agent:ask_notte:124 - Picking Notte endpoint: step
# 2025-01-29 17:06:14.212 | INFO     | notte.env:execute:160 - 🌌 action B1 executed in browser
# 2025-01-29 17:06:14.250 | INFO     | notte.common.logging:wrapper:16 - function execute took 1.4023 seconds
# 2025-01-29 17:06:14.251 | DEBUG    | notte.env:step:231 - ℹ️ previous actions IDs: []
# 2025-01-29 17:06:14.252 | DEBUG    | notte.env:step:232 - ℹ️ context inodes IDs: ['B1', 'B2', 'L1', 'L2', 'L3', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'L10', 'L11', 'L12', 'L13', 'L14', 'L15', 'L16', 'L17', 'L18', 'L19', 'L20', 'L21', 'L22']
# 2025-01-29 17:06:14.262 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1700 tokens
# 2025-01-29 17:06:28.647 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B1 | Sign up for an account using Google | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.650 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | B2 | Sign up for an account using Apple | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.651 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L1 | Create a new account | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.652 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L2 | View the Terms of Service | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.652 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L3 | View the Privacy Policy | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.653 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L4 | View the Cookie Use policy | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.654 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L5 | Sign in to your existing account | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.654 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L6 | Learn more about the platform | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.654 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L7 | Download the mobile app | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.655 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L8 | Access the Help Center | None | Help & Support | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.655 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L9 | Review the Terms of Service | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.656 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L10 | Review the Privacy Policy | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.656 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L11 | Review the Cookie Policy | None | Legal & Policy | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.657 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L12 | Learn about Accessibility features | None | Help & Support | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.658 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L13 | View Ads information | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.658 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L14 | Read the Blog for insights and updates | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.658 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L15 | Explore Careers opportunities | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.659 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L16 | Access Brand Resources | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.659 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L17 | Learn about Advertising on the platform | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.659 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L18 | Access Marketing resources | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.660 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L19 | Discover options for X for Business | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.660 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L20 | Access Developer resources | None | User Account | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.660 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L21 | Browse the Directory | None | Discovery & Exploration | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.661 | WARNING  | notte.actions.parsing:parse_table:331 - [Markdown table parsing] Failed to parse action line: | L22 | Access account Settings | None | Settings & Preferences | with error: Failed to parse LLM response. Name and type are required fields but not found in : None  Please try again later.
# 2025-01-29 17:06:28.663 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 24 : {'L8', 'L17', 'L19', 'B1', 'L21', 'L11', 'L14', 'L18', 'L3', 'L10', 'L13', 'L6', 'L12', 'L1', 'L16', 'L2', 'B2', 'L7', 'L5', 'L20', 'L9', 'L22', 'L4', 'L15'}
# 2025-01-29 17:06:28.663 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 24 total, 22 required for completion but only 0 listed
# 2025-01-29 17:06:28.663 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 3 trials left.
# 2025-01-29 17:06:28.687 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1700 tokens
# 2025-01-29 17:06:41.485 | WARNING  | notte.pipe.validation:forward:26 - Missed actions: 7 : {'L16', 'L17', 'L19', 'L18', 'L22', 'L21', 'L20'}
# 2025-01-29 17:06:41.486 | WARNING  | notte.pipe.main:check_enough_actions:120 - Not enough actions listed: 24 total, 22 required for completion but only 17 listed
# 2025-01-29 17:06:41.487 | INFO     | notte.pipe.main:forward_unfiltered:158 - [ActionListing] Retry listing actions with 2 trials left.
# 2025-01-29 17:06:41.509 | INFO     | notte.pipe.listing:forward_incremental:154 - 🚀 Forward incremental reduces context length by 75.68%
# 2025-01-29 17:06:41.515 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 1717 tokens
# 2025-01-29 17:06:47.848 | INFO     | notte.pipe.main:check_enough_actions:97 - [ActionListing] Enough actions: 24 >= 22. Stop action listing prematurely.
# 2025-01-29 17:06:47.858 | DEBUG    | notte.llms.service:get_base_model:44 - llm router 'fixed' selected 'openai/gpt-4o-mini' for approx 580 tokens
# 2025-01-29 17:06:59.676 | INFO     | notte.pipe.document_category:forward:33 - 🏷️ Page categorisation: homepage (took 11.83 seconds)
# 2025-01-29 17:06:59.828 | INFO     | notte.common.logging:wrapper:16 - function step took 46.9803 seconds
# 2025-01-29 17:06:59.829 | INFO     | examples.agent:run:208 - 🌌
# Webpage information:
# - URL: https://x.com/?mx=2
# - Title: X. It’s what’s happening / X
# - Description: This document outlines the footer navigation of the "WebArea X" website, which contains links to various resources and services related to branding, advertising, marketing, and business solutions. Users are expected to click on these links to access more detailed information about each service.
# - Timestamp: 2025-01-29 17:06:14
# - Page category: homepage
#
# Here are the available actions you can take on this paqe:
#
# <actions>
# # Discovery &amp; Exploration
# * L13: Get Ads information
# * L14: Read the company blog
# * L15: Explore career opportunities at X
# * L16: Access the Brand Resources page
# * L17: Access the Advertising information
# * L18: Access the Marketing resources
# * L19: Access information on X for Business
# * L20: Access the Developers resources
# * L21: Access the Directory of services
# * L22: Access the Settings page
# * L6: Learn more about the company
# * L7: Download the X app
#
# # User Account
# * B1: Sign up for an account using Google
# * B2: Sign up for an account using Apple
# * L1: Create a new account
# * L5: Sign in to an existing account
#
# # Legal &amp; Policy
# * L10: View the Privacy Policy
# * L11: View the Cookie Policy
# * L12: Learn about Accessibility options
# * L2: View the Terms of Service
# * L3: View the Privacy Policy
# * L4: View the Cookie Use policy
# * L9: View the Terms of Service
#
# # Help &amp; Support
# * L8: Access the Help Center
#
# # Special Browser Actions
# * S1: Go to a specific URL ([ActionParameter(name='url', type='string', default=None, values=[])])
# * S2: Scrape data from the current page
# * S3: Take a screenshot of the current page
# * S4: Go to the previous page
# * S5: Go to the next page
# * S6: Refresh the current page
# * S7: Wait for a specific amount of time (in seconds) ([ActionParameter(name='wait_time_seconds', type='int', default=None, values=[])])
# * S8: Terminate the current session
# </actions>
#
# Now think about your current trajectory, and decide what action to take next.
# You might need to perform some intermediate actions so be very careful, dont jump to conclusions too quickly.
#
# Provide me with the ID of the action you want to take next.
# You are allowed to take only exactly ONE action from this list (not previous lists)!
# If the action is parameterized, provide the value for each parameter.
# Use the exact following format:
#
# <execute-action>
# {
# "action_id": "<YOUR_ACTION_ID>",
# "params": { "<YOUR_PARAM_NAME>": "<YOUR_PARAM_VALUE>" }
# }
# </execute-action>
#
# Important rules:
# * If you're done, include you final answer in <done> tags.
# Don't forget to justify why your answer is correct and solves the task.
# Don't assume anything, just provide factual information backup by the page you're on.
# * If you are not done, provide the action you want to take next in <execute-action> tags.
# * If you want to stop or you're unable to pursue your goal, just explain your problem
# inside <done>Error: ... </done> tags.
# * You are allowed to take only exactly ONE action from the list.
# * You are ONLY allowed to pick actions from the latest list of actions!
# * You are NOT allowed to pick actions from list of actions in previous messages!
# * If you feel stuck, remember that you are allowed to use `Special Browser Actions` at any time to:
#     * Go to a different url
#     * Go back to the previous page
#     * Refresh the current page
#     * Scrape data from the page
#     * Etc
#
#
# 2025-01-29 17:06:59.829 | INFO     | examples.agent:run:190 - > step 2: looping in
# 2025-01-29 17:07:00.561 | INFO     | examples.agent:run:194 - 🤖 <execute-action>
# {
# "action_id": "L5",
# "params": {}
# }
# </execute-action>
# 2025-01-29 17:07:00.563 | DEBUG    | examples.agent:ask_notte:124 - Picking Notte endpoint: step
# 2025-01-29 17:07:01.928 | INFO     | notte.env:execute:160 - 🌌 action L5 executed in browser
# 2025-01-29 17:07:01.940 | WARNING  | notte.pipe.preprocessing.a11y.pruning:should_prune:59 - Role `dialog` has an empty name and no children. Please considered adding it to `prune_roles`
# 2025-01-29 17:07:01.940 | WARNING  | notte.pipe.preprocessing.a11y.pruning:should_prune:59 - Role `dialog` has an empty name and no children. Please considered adding it to `prune_roles`
# 2025-01-29 17:07:02.009 | INFO     | notte.browser.pool:_close_browser:269 - Closing browser 00197c4d-c3e1-4c6b-905b-456f5dd18b2c
# ---------------------------------------------------------------------------
# NodeFilteringResultsInEmptyGraph          Traceback (most recent call last)
# Cell In[1], line 14
#      12 # Run the agent directly with await
#      13 task = "Post 'Hello World' on Twitter"
# ---> 14 result = await agent.run(
#      15     task=task,
#      16     url="https://x.com"  # Credentials will be loaded automatically
#      17 )
#      18 print(result)
#
# File ~/DEV/Notte/password_manager/notte/examples/agent.py:206, in SimpleNotteAgent.run(self, task, url)
#     199     return AgentOutput(
#     200         answer=done_answer,
#     201         success=("Error: " not in done_answer),
#     202         snapshot=self.env.context.snapshot,
#     203         messages=messages,
#     204     )
#     205 # Ask Notte to perform the selected action
# --> 206 obs: str = await self.ask_notte(resp)
#     207 messages.append({"role": "user", "content": obs})
#     208 logger.info(f"🌌 {obs}")
#
# File ~/DEV/Notte/password_manager/notte/examples/agent.py:132, in SimpleNotteAgent.ask_notte(self, text)
#     130 case "step":
#     131     step_params = self.parser.step(text)
# --> 132     obs = await self.env.step(step_params.action_id, step_params.params)
#     133     return self.parser.textify(obs)
#     134 case "scrape":
#     135     # TODO: parse URL if needed
#
# File ~/DEV/Notte/password_manager/notte/notte/common/logging.py:14, in timeit.<locals>._timeit.<locals>.wrapper(*args, **kwargs)
#      12 async def wrapper(*args: Any, **kwargs: Any) -> Any:
#      13     start_time = time.time()
# ---> 14     result = await func(*args, **kwargs)
#      15     end_time = time.time()
#      16     logger.info(f"function {name} took {end_time - start_time:.4f} seconds")
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:230, in NotteEnv.step(self, action_id, params, enter, min_nb_actions, max_nb_actions)
#     221 @timeit("step")
#     222 async def step(
#     223     self,
#    (...)
#     228     max_nb_actions: int = DEFAULT_MAX_NB_ACTIONS,
#     229 ) -> Observation:
# --> 230     _ = await self.execute(action_id, params, enter=enter)
#     231     logger.debug(f"ℹ️ previous actions IDs: {[a.id for a in self.previous_actions or []]}")
#     232     logger.debug(f"ℹ️ context inodes IDs: {[node.id for node in self.context.interaction_nodes()]}")
#
# File ~/DEV/Notte/password_manager/notte/notte/common/logging.py:14, in timeit.<locals>._timeit.<locals>.wrapper(*args, **kwargs)
#      12 async def wrapper(*args: Any, **kwargs: Any) -> Any:
#      13     start_time = time.time()
# ---> 14     result = await func(*args, **kwargs)
#      15     end_time = time.time()
#      16     logger.info(f"function {name} took {end_time - start_time:.4f} seconds")
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:161, in NotteEnv.execute(self, action_id, params, enter)
#     159 snapshot = await ExecutionPipe.forward(action, _params, self.context, self._browser, enter=enter)
#     160 logger.info(f"🌌 action {action_id} executed in browser")
# --> 161 return self._preobserve(snapshot)
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:99, in NotteEnv._preobserve(self, snapshot)
#      97 if self._max_steps is not None and len(self._trajectory) >= self._max_steps:
#      98     raise MaxStepsReachedError(max_steps=self._max_steps)
# ---> 99 self._context = BrowserSnapshotToContextPipe.forward(snapshot)
#     100 preobs = Observation.from_snapshot(snapshot)
#     101 self._trajectory.append(preobs)
#
# File ~/DEV/Notte/password_manager/notte/notte/env.py:34, in BrowserSnapshotToContextPipe.forward(snapshot)
#      32 @staticmethod
#      33 def forward(snapshot: BrowserSnapshot) -> Context:
# ---> 34     return ActionA11yPipe.forward(snapshot)
#
# File ~/DEV/Notte/password_manager/notte/notte/pipe/preprocessing/a11y/pipe.py:14, in ActionA11yPipe.forward(snapshot)
#      12 @staticmethod
#      13 def forward(snapshot: BrowserSnapshot) -> Context:
# ---> 14     processed_tree = ProcessedA11yTree.from_a11y_tree(snapshot.a11y_tree)
#      15     return Context(
#      16         snapshot=snapshot,
#      17         node=NotteNode.from_a11y_node(
#    (...)
#      20         ),
#      21     )
#
# File ~/DEV/Notte/password_manager/notte/notte/pipe/preprocessing/a11y/tree.py:60, in ProcessedA11yTree.from_a11y_tree(tree)
#      58 processed_tree = simple_processing_accessiblity_tree(_processed_tree)
#      59 if processed_tree is None:
# ---> 60     raise NodeFilteringResultsInEmptyGraph("pruning processed tree")
#      61 processed_tree = sync_ids_between_trees(source=simple_tree, target=processed_tree)
#      62 # manually sync image IDs between trees
#
# NodeFilteringResultsInEmptyGraph: Operation 'filtering' resulted in an empty graph. Notte always expect a non-empty graph. Please check the `pruning.py` file or `subtree_without` method for more information.
